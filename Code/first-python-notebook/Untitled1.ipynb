# %% [markdown]
# # First Python Notebook
# Hell world!

# %%
number = 10

# %%
number * number
# Out:
# 100

# %%
import pandas

# %%
import pandas as pd

# %%
my_list = [2, 4, 6, 8]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 20

# %%
my_series.max()
# Out:
# 8

# %%
my_series.min()
# Out:
# 2

# %%
my_series.mean()
# Out:
# 5.0

# %%
my_series.median()
# Out:
# 5.0

# %%
my_series.std()
# Out:
# 2.581988897471611

# %%
my_series.describe()
# Out:
# count    4.000000
# mean     5.000000
# std      2.581989
# min      2.000000
# 25%      3.500000
# 50%      5.000000
# 75%      6.500000
# max      8.000000
# dtype: float64

# %%
import pandas

# %%
import pandas as pd

# %%
pd.read_csv("https://first-python-notebook.readthedocs.io/_static/committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props = pd.read_csv("https://first-python-notebook.readthedocs.io/_static/committees.csv")

# %%
props.head
# Out:
# <bound method NDFrame.head of                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# ...

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.5+ KB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.5+ KB

# %%
contribs = pd.read_csv("https://first-python-notebook.readthedocs.io/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 10  PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 11  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# 12  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# ...

# %%
props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %%
props[props.prop_name == 'PROPOSITION 06*']
# Out:
# Empty DataFrame
# Columns: [ocd_prop_id, calaccess_prop_id, ccdc_prop_id, prop_name, ccdc_committee_id, calaccess_committee_id, committee_name, committee_position]
# Index: []

# %%
props[props.prop_name == 'PROPOSITION 06**']
# Out:
# Empty DataFrame
# Columns: [ocd_prop_id, calaccess_prop_id, ccdc_prop_id, prop_name, ccdc_committee_id, calaccess_committee_id, committee_name, committee_position]
# Index: []

# %%
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
prop.value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-8c37ef3e2738> in <module>()
# ----> 1 prop.value_count()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_count'

# %%
prop.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-2f8e3bba5c8c> in <module>()
# ----> 1 prop.value_counts()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
prop.prop_name.value_counts()
# Out:
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.    11
# Name: prop_name, dtype: int64

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.5+ KB

# %%
merged = pd.merge(prop, contribs, on='calaccess_committee_id')

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
merged.info()

# %%
merged.amount
# Out:
# 0          100.00
# 1       250000.00
# 2       250000.00
# 3       250000.00
# 4       250000.00
# 5       250000.00
# 6          100.00
# 7          100.00
# 8          100.00
# 9       250000.00
# 10      250000.00
# 11      250000.00
# 12      250000.00
# 13      250000.00
# 14        1000.00
# 15         100.00
# 16         100.00
# 17         100.00
# 18          25.00
# 19         100.00
# 20         100.00
# 21         100.00
# 22         100.00
# 23         100.00
# 24      250000.00
# 25         100.00
# 26         100.00
# 27         100.00
# 28          20.00
# 29        1000.00
#           ...
# 830       1000.00
# 831        250.00
# 832        250.00
# 833        800.00
# 834        400.00
# 835      14000.00
# 836      35000.00
# 837     120000.00
# 838      45000.00
# 839    1000000.00
# 840     150000.00
# 841     250000.00
# 842     250000.00
# 843     550000.00
# 844     420000.00
# 845    1000000.00
# 846    1970000.00
# 847      30000.00
# 848     550000.00
# ...

# %%
merged.amount.sum

# %%
merged.amount.sum()m
# Out:
# 35177017.64

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    762
# OPPOSE      98
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged [merged.committee_position == 'OPPOSE']

# %%
oppose.amount.sum()
# Out:
# 2501211.64

# %%
support.amount.sum()
# Out:
# 32675806.0

# %%
support.amount.sum()/merged.amount.sum()
# Out:
# 0.9288964270479867

# %%
support.amount.sum()/merged.amount.sum()*100
# Out:
# 92.88964270479867

# %%
support.amount.sum()/merged.amount.sum()*100%

# %%
merged.sort_values("amount")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 260  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 793  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 806  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 727  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 698  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 227  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 812  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 127  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 118  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 220  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 101  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 28   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.sort_values("amount", ascending = False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 141  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 143  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 253  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 259  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 850  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 142            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 79             83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 846            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 851            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 852            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 142                456                 1381808
# ...

# %%
support.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-241c2fe82bff> in <module>()
# ----> 1 support.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
support.sort_values("amount", ascending =False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 142            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 79             83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 851            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 846            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 852            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 142                456                 1381808
# ...

# %%
oppose.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-c71f6683954a> in <module>()
# ----> 1 oppose.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
oppose.sort_values("amount", ascending =False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 840  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 839            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 312            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 310            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 308            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 840            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 839                463                 1387789
# ...

# %%
merged.groupby("committee_name_x").amount.sum()
# Out:
# committee_name_x
# ADULT USE CAMPAIGN FOR PROPOSITION 64; THE                                                                                                                                                              17089.00
# CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM, SPONSORED BY DRUG POLICY ACTION, YES ON PROP. 64                                                                                                        860470.00
# CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY GHOST MANAGEMENT GROUP, LLC DBA WEEDMAPS                                                                                                                850000.00
# DRUG POLICY ACTION - NON PROFIT 501C4, YES ON PROP. 64                                                                                                                                                4470000.00
# ...

# %% [raw]
# merged.groupby("committee_name_x").amount.sum().reset_index()

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#                                      committee_name_x       amount
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending =False)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 482                  SEAN                          PARKER            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 108                DANIEL                           LEWIS            SUPPORT
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# 405              NICHOLAS                        PRITZKER            SUPPORT
# 421                 PETER                           THIEL            SUPPORT
# 456                 ROGER                         JENKINS            SUPPORT
# 23                 ANGELA                          HOWARD            SUPPORT
# 322              LAWRENCE                            HESS            SUPPORT
# 221                 JASON                            POST            SUPPORT
# ...

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
merged.amount.sum("contributor_state")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-eab3886d4b25> in <module>()
# ----> 1 merged.amount.sum("contributor_state")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9591                                       skipna=skipna, min_count=min_count)
#    9592         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9593                             numeric_only=numeric_only, min_count=min_count)
#    9594
#    9595     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3214             # Validate that 'axis' is consistent with Series's single axis.
#    3215             if axis is not None:
# ...

# %%
merged.groupby("contributor_state").amount.sum()
# Out:
# contributor_state
# AB           0.00
# AL         100.00
# AZ         500.00
# BC           0.00
# CA    17491193.00
# CO       39300.00
# CT         100.00
# DC     2618600.00
# DE     6140100.00
# FL     1250850.00
# GA         100.00
# ID        1000.00
# IL        7000.00
# LA         100.00
# MA         600.00
# MD        2971.00
# MI         400.00
# MO         550.00
# NC         200.00
# NV        1800.00
# NY     5446985.00
# OH        2950.00
# OK         200.00
# OR        1400.00
# PA     1215475.00
# RI        6700.00
# TX        1800.00
# VA      895243.64
# WA       50800.00
# Name: amount, dtype: float64

# %%
merged.sort_values("contributor_state", ascending = False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 20   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 256  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 359  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 397  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 398  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 560  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 403  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 485  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 506  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 500  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 291  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 287  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
merged.contributor_state.value_counts()
# Out:
# CA    693
# CO     25
# NY     18
# DC     12
# PA     12
# WA     10
# IL     10
# VA     10
# FL     10
# DE      9
# MO      6
# NV      6
# AZ      5
# MA      4
# OH      4
# OR      4
# TX      4
# MD      3
# OK      2
# AB      2
# BC      2
# MI      2
# RI      1
# NC      1
# AL      1
# ID      1
# GA      1
# CT      1
# LA      1
# Name: contributor_state, dtype: int64

# %%
merged.amount.sum("contributor_state" == 'CA')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-98422ae5066f> in <module>()
# ----> 1 merged.amount.sum("contributor_state" == 'CA')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9591                                       skipna=skipna, min_count=min_count)
#    9592         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9593                             numeric_only=numeric_only, min_count=min_count)
#    9594
#    9595     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3214             # Validate that 'axis' is consistent with Series's single axis.
#    3215             if axis is not None:
# ...

# %%
CA_Donor = merged[merged.contributor_state == "CA"]

# %%
CA_Donor.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 6            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
CA_Donor.amount.sum()
# Out:
# 17491193.0

# %%
CA_Donor.amount.sum()/merged.amount.sum()
# Out:
# 0.49723353977884294

# %%
CA_Donor.amount.sum()/merged.amount.sum() *100
# Out:
# 49.723353977884294

# %%
merged.amount.sum()
# Out:
# 35177017.64

# %%
Other_Donor = merged[merged.contributor_state != "CA"]

# %%
Other_Donor.amount.sum()
# Out:
# 17685824.64

# %%
support.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
merged.groupby("contributor_employer")

# %%
merged.groupby("contributor_employer").sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-2623b17d3fe8> in <module>()
# ----> 1 merged.groupby("contributor_employer").sort_values()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %%
support.sort_values("contributor_employer")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 635  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 522  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 452  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 699  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 689  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 543  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 809  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 612  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 478  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 747  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 618  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 639  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
support.groupby("contributor_employer").amount.sum()
# Out:
# contributor_employer
# 360SWEATER COMPANY, LLC                       360.0
# 3C - COMPREHENSIVE CANNABIS CONSULTING        100.0
# 4FRONT VENTURES                               100.0
# 5AM VENTURES                                  500.0
# 745 AGENCY                                    250.0
# 7TH POINT, LLC                                100.0
# A NEW PATH                                     84.0
# ACLU OF SAN DIEGO & IMPERIAL COUNTIES         250.0
# AD PRODUCTIONS, LLC                           100.0
# ADAM ELLIS                                    100.0
# ADR SERVICES                                  300.0
# AGZAAR                                        200.0
# AJA VIDEO SYSTEMS                             100.0
# AKONADI FOUNDATION                           5000.0
# ALAN CRAWFORD                                 100.0
# ALAN SPARER                                   250.0
# ALEX HALPERIN                                 100.0
# ALLIANCE ENGINEERING                          100.0
# ...

# %%
support.groupby("contributor_employer").value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-ac096259f388> in <module>()
# ----> 1 support.groupby("contributor_employer").value_counts()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
# --> 765                              (type(self).__name__, attr))
#     766
#     767     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
merged.contributor_employer.value_counts()
# Out:
# NONE                                       94
# RETIRED                                    10
# LOS ANGELES DEPARTMENT OF WATER & POWER     7
# STATE OF CALIFORNIA                         6
# APPLE, INC.                                 6
# SOUTHERN CALIFORNIA EDISON                  5
# NETZER & MALMO                              5
# JULIE JOLLEY                                5
# SELF                                        5
# BOSTON SCIENTIFIC                           5
# MICROSOFT                                   5
# SQUARECHICKEN MEDIA                         4
# MOTOROLA                                    4
# USA TRUCK                                   4
# DESIGN OCTAVES, INC.                        4
# LONZA BIOSCIENCE                            3
# THE SEASTEADING INSTITUTE                   3
# TORTUGA ADVISERS LLC                        3
# KHURSID KHOJA                               3
# MCELFRESH LAW                               3
# ...

# %%
support.contributor_employer.value_counts()
# Out:
# NONE                                              92
# LOS ANGELES DEPARTMENT OF WATER & POWER            7
# RETIRED                                            6
# APPLE, INC.                                        6
# MICROSOFT                                          5
# SOUTHERN CALIFORNIA EDISON                         5
# NETZER & MALMO                                     5
# JULIE JOLLEY                                       5
# DESIGN OCTAVES, INC.                               4
# SQUARECHICKEN MEDIA                                4
# USA TRUCK                                          4
# MOTOROLA                                           4
# REQUESTED                                          3
# TORTUGA ADVISERS LLC                               3
# TEKSYSTEMS                                         3
# KHURSID KHOJA                                      3
# OLD HOME POTTERY                                   3
# CM COLLINS ASSOCIATION, INC.                       3
# ...

# %%
oppose.contributor_employer.value_counts()
# Out:
# BOSTON SCIENTIFIC                         5
# RETIRED                                   4
# STATE OF CALIFORNIA                       4
# SELF                                      3
# NONE                                      2
# CITY OF SUNNYVALE                         2
# CSI                                       2
# CITY OF ROCKLIN                           1
# CITY OF ARCADIA                           1
# AEROWIND CORP                             1
# GLOBALWIDE MEDIA                          1
# CITY OF LOS ALAMITOS POLICE DEPARTMENT    1
# SFWKC                                     1
# CITY OF HUNTINGTON BEACH                  1
# LA COUNTY                                 1
# SEFF                                      1
# SCOTT SEAMAN CONSULTING                   1
# AMADOR COUNTY SHERIFF'S OFFICE            1
# CALIFORNIA INSTITUTE OF TECHNOLOGY        1
# NON                                       1
# CITY OF VENTURA                           1
# ...

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
merged.committee_name_x.value_counts()
# Out:
# CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM, SPONSORED BY DRUG POLICY ACTION, YES ON PROP. 64                                                                                                      420
# YES ON 64, CALIFORNIANS TO CONTROL, REGULATE AND TAX ADULT USE OF MARIJUANA WHILE PROTECTING CHILDREN, SPONSORED BY BUSINESS, PHYSICIANS, ENVIRONMENTAL AND SOCIAL-JUSTICE ADVOCATE ORGANIZATIONS    250
# PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64, SPONSORED AND MAJOR FUNDING BY SAM ACTION, INC. AND CALIFORNIA PUBLIC SAFETY INSTITUTE                                                                 88
# MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64                                                                                                                                                     40
# ...

# %%
merged.committee_name_x.value_counts().reset_index()
# Out:
#                                                 index  committee_name_x
# 0   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...               420
# 1   YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...               250
# 2   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...                88
# 3   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64                40
# 4          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE                26
# 5                              NEW APPROACH PAC (MPO)                 9
# 6        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))                 8
# 7   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...                 7
# 8   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...                 6
# 9                         MOMS STRONG AGAINST PROP 64                 4
# 10  CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...                 2

# %%
support.committee_name_x.value_counts().reset_index()
# Out:
#                                                index  committee_name_x
# 0  CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...               420
# 1  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...               250
# 2  MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64                40
# 3         ADULT USE CAMPAIGN FOR PROPOSITION 64; THE                26
# 4                             NEW APPROACH PAC (MPO)                 9
# 5       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))                 8
# 6  DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...                 7
# 7  CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...                 2

# %%
oppose.committee_name_x.value_counts()
# Out:
# PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64, SPONSORED AND MAJOR FUNDING BY SAM ACTION, INC. AND CALIFORNIA PUBLIC SAFETY INSTITUTE    88
# SAM ACTION, INC., A COMMITTEE AGAINST PROPOSITION 64 WITH HELP FROM CITIZENS (NONPROFIT 501 (C)(4))                                       6
# MOMS STRONG AGAINST PROP 64                                                                                                               4
# Name: committee_name_x, dtype: int64

# %%
oppose.committee_name_x.value_counts().reset_index()
# Out:
#                                                index  committee_name_x
# 0  PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...                88
# 1  SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...                 6
# 2                        MOMS STRONG AGAINST PROP 64                 4

# %%
merged.amount.sum()
# Out:
# 35177017.64

# %%
support.amount.sum()
# Out:
# 32675806.0

# %%
oppose.amount.sum()/merged.amount.sum()
# Out:
# 0.07110357295201333

# %%
merged.amount.value_counts()
# Out:
#  100.00        367
#  250.00         71
#  50.00          56
#  25.00          43
#  200.00         43
#  500.00         40
#  1000.00        34
#  5000.00        25
#  250000.00      21
#  300.00         16
#  2500.00        14
#  10000.00        9
#  150.00          8
#  1000000.00      8
#  400.00          7
#  2000.00         5
#  500000.00       4
#  25000.00        4
#  10.00           4
#  200000.00       4
#  84.00           4
# -100.00          3
#  420000.00       3
#  550000.00       3
#  1970000.00      2
#  400000.00       2
#  75.00           2
#  198.00          2
#  99.00           2
#  3000.00         2
#               ...
#  42.00           1
#  110.00          1
#  30.00           1
#  75000.00        1
#  800.00          1
#  1403000.00      1
#  225000.00       1
#  30000.00        1
#  871.00          1
#  35000.00        1
#  4000000.00      1
#  97000.00        1
#  120000.00       1
#  817.00          1
#  408.64          1
#  4185.00         1
# ...

# %%
oppose.groupby("amount")

# %%
oppose.groupby("amount").amount.sum()
# Out:
# amount
# 50.00              50.00
# 100.00           2000.00
# 130.00            130.00
# 150.00            450.00
# 200.00           1200.00
# 250.00           1250.00
# 300.00            900.00
# 400.00            800.00
# 408.64            408.64
# 500.00           3500.00
# 817.00            817.00
# 871.00            871.00
# 1000.00          6000.00
# 2000.00          4000.00
# 2500.00          5000.00
# 4185.00          4185.00
# 5000.00         70000.00
# 6500.00          6500.00
# 10000.00        50000.00
# 12500.00        25000.00
# 14000.00        14000.00
# 18150.00        18150.00
# 25000.00        75000.00
# 35000.00        35000.00
# 36000.00        36000.00
# 45000.00        45000.00
# 120000.00      120000.00
# 150000.00      150000.00
# 200000.00      200000.00
# 225000.00      225000.00
# 400000.00      400000.00
# 1000000.00    1000000.00
# Name: amount, dtype: float64

# %%
merged.amount.median()
# Out:
# 100.0

# %%
merged.groupby("committee_name_x").amount.median().reset_index()
# Out:
#                                      committee_name_x    amount
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     198.0
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...     100.0
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...  425000.0
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...  420000.0
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  525000.0
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64     225.0
# 6                         MOMS STRONG AGAINST PROP 64     844.0
# 7                              NEW APPROACH PAC (MPO)  250000.0
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...     500.0
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   82500.0
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...     100.0

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                      committee_name_x       amount
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00

# %%
oppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 261  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 262  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 263  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 264  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 265  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 261            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 262            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 263            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 264            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 265            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 261                459                 1382568
# ...

# %%
oppose.sort_values("prop_name", ascending = False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 261  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 334  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 332  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 331  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 330  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 329  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 328  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 327  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 326  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 325  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 324  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 323  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...
